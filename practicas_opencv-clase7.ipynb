# %% [markdown]
# <a href="https://colab.research.google.com/github/marcehluna/VC/blob/main/practicas_opencv-clase7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('imagen_prueba.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)


h,s,v = cv2.split(img_hsv)


v_new = cv2.convertScaleAbs(v, alpha=0.5, bet)

hsv_new = cv2.merge([h,s,v_new])

cv2_imshow(hsv_new)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

rostros = face_cascade.detectMultiScale(img_gray, scaleFactor=1.1, minNeighbors=5)


for (x, y, w, h) in rostros:
    cv2.rectangle(img, (x, y), (x + w, y + h), (255, 255, 0), 5)


print(f"Se encontraron {len(rostros)} rostros")
cv2_imshow(img)
# Out:
# Se encontraron 1 rostros
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
cv2.imwrite(nombre_archivo, rostro)
